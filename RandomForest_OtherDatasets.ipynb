# %% [markdown]
# > **Name: Shriya Bhat**
# <br>
# **Section: A1**
# <br>
# **Registration Number: 220968020**
# <br>
# **Week: 5**<br>
# File 4 <br>
# Job Offers dataset - `Random Froest`
# <br>
# Heart Disease dataset - `Random Forest`
# <br>
# Bands dataset - `Random Forest`

# %% [markdown]
# ### Required Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_graphviz, plot_tree

# %% [markdown]
# _`sklearn` does not support categorical data for finding random forest, we one hot encode the data so that it becomes numeric.<br>_

# %% [markdown]
# ### 2) Job Offers Data

# %% [markdown]
# - Import the dataset.

# %%
job_data: pd.DataFrame = pd.read_csv(
    r"..\Datasets\Week5\job_offers.csv",
    dtype="category"
)
job_data
# Out:
#   CGPA Interactive Practical Knowledge    Skills Job Offer
# 0  >=9         Yes           Very good      Good       Yes
# 1  >=8          No                Good  Moderate       Yes
# 2  >=9          No             Average      Poor        No
# 3   <8          No             Average      Good        No
# 4  >=8         Yes                Good  Moderate       Yes
# 5  >=9         Yes                Good  Moderate       Yes
# 6   <8         Yes                Good      Poor        No
# 7  >=9          No           Very good      Good       Yes
# 8  >=8         Yes                Good      Good       Yes
# 9  >=8         Yes             Average      Good       Yes

# %% [markdown]
# - One hot encode the data to make it numeric.

# %%
job_coded: pd.DataFrame = pd.get_dummies(job_data, columns=[i for i in job_data.columns if i != "Job Offer"])
job_coded
# Out:
#   Job Offer  CGPA_<8  CGPA_>=8  CGPA_>=9  Interactive_No  Interactive_Yes  \
# 0       Yes    False     False      True           False             True
# 1       Yes    False      True     False            True            False
# 2        No    False     False      True            True            False
# 3        No     True     False     False            True            False
# 4       Yes    False      True     False           False             True
# 5       Yes    False     False      True           False             True
# 6        No     True     False     False           False             True
# 7       Yes    False     False      True            True            False
# 8       Yes    False      True     False           False             True
# 9       Yes    False      True     False           False             True
#
#    Practical Knowledge_Average  Practical Knowledge_Good  \
# 0                        False                     False
# ...

# %% [markdown]
# - Define feature vector and target variable.

# %% [markdown]
# *Feature vector:*

# %%
x: pd.DataFrame = job_coded.iloc[:, 1:]

# %% [markdown]
# *Target Variable:*

# %%
y: pd.Series = job_coded["Job Offer"]

# %% [markdown]
# - Create training and testing splits.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# *Training data:*

# %%
pd.concat([x_train, y_train], axis=1)
# Out:
#    CGPA_<8  CGPA_>=8  CGPA_>=9  Interactive_No  Interactive_Yes  \
# 0    False     False      True           False             True
# 7    False     False      True            True            False
# 2    False     False      True            True            False
# 9    False      True     False           False             True
# 4    False      True     False           False             True
# 3     True     False     False            True            False
# 6     True     False     False           False             True
#
#    Practical Knowledge_Average  Practical Knowledge_Good  \
# 0                        False                     False
# 7                        False                     False
# 2                         True                     False
# 9                         True                     False
# 4                        False                      True
# 3                         True                     False
# ...

# %% [markdown]
# *Testing data:*

# %%
pd.concat([x_test, y_test], axis=1)
# Out:
#    CGPA_<8  CGPA_>=8  CGPA_>=9  Interactive_No  Interactive_Yes  \
# 8    False      True     False           False             True
# 1    False      True     False            True            False
# 5    False     False      True           False             True
#
#    Practical Knowledge_Average  Practical Knowledge_Good  \
# 8                        False                      True
# 1                        False                      True
# 5                        False                      True
#
#    Practical Knowledge_Very good  Skills_Good  Skills_Moderate  Skills_Poor  \
# 8                          False         True            False        False
# 1                          False        False             True        False
# 5                          False        False             True        False
#
#   Job Offer
# 8       Yes
# 1       Yes
# 5       Yes

# %% [markdown]
# - Create classifier.

# %%
model: RandomForestClassifier = RandomForestClassifier(criterion="entropy", random_state=42)
model
# Out:
# RandomForestClassifier(criterion='entropy', random_state=42)

# %% [markdown]
# - Fit the model.

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=42)

# %% [markdown]
# - Plot the tree.

# %% [markdown]
# *A random forest contains multiple estimator trees which are used to find the optimal decision tree for calculation. To find the best tree for the data, we use the majority voting technique. Fitting all trees with same data and predicting results from same test sample, we can find a tree with the highest accuracy. This tree will be our required decision tree.*

# %%
# Convert categories into numeric data
# Because the trees are fitted with numeric codes for the categories
accuracies: list[float] = [accuracy_score(y_test.cat.codes, i.predict(x_test)) for i in model.estimators_]
req_tree: DecisionTreeClassifier = model.estimators_[accuracies.index(max(accuracies))]
req_tree
# Out:
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# ...

# %% [markdown]
# *Using `sklearn.tree.plot_tree`:*

# %%
plot_tree(
    req_tree,
    feature_names=x.columns,
    class_names=y.unique(),
    rounded=True,
    filled=True
)
# Out:
# [Text(0.4, 0.8333333333333334, 'Practical Knowledge_Average <= 0.5\nentropy = 0.985\nsamples = 4\nvalue = [3, 4]\nclass = No'),
#  Text(0.2, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 3]\nclass = No'),
#  Text(0.6, 0.5, 'Skills_Good <= 0.5\nentropy = 0.811\nsamples = 2\nvalue = [3, 1]\nclass = Yes'),
#  Text(0.4, 0.16666666666666666, 'entropy = 0.0\nsamples = 1\nvalue = [3, 0]\nclass = Yes'),
#  Text(0.8, 0.16666666666666666, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No')]

# %% [markdown]
# *Using `sklearn.tree.export_graphviz`:*

# %%
with open(r"Generated/job_rf.txt", "x") as file:
    content: str = export_graphviz(
        req_tree,
        feature_names=x.columns,
        class_names=y.unique(),
        rounded=True,
        filled=True
    )
    file.write(content)
    print(content)
    file.close()
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label="Practical Knowledge_Average <= 0.5\nentropy = 0.985\nsamples = 4\nvalue = [3, 4]\nclass = No", fillcolor="#cee6f8"] ;
# 1 [label="entropy = 0.0\nsamples = 2\nvalue = [0, 3]\nclass = No", fillcolor="#399de5"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="Skills_Good <= 0.5\nentropy = 0.811\nsamples = 2\nvalue = [3, 1]\nclass = Yes", fillcolor="#eeab7b"] ;
# 0 -> 2 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 3 [label="entropy = 0.0\nsamples = 1\nvalue = [3, 0]\nclass = Yes", fillcolor="#e58139"] ;
# 2 -> 3 ;
# 4 [label="entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No", fillcolor="#399de5"] ;
# 2 -> 4 ;
# }

# %% [markdown]
# - Predict values for test set.

# %%
temp_data: pd.DataFrame = job_data.loc[x_test.index, :]
temp_data["Predicted_Class"] = model.predict(x_test)

temp_data
# Out:
#   CGPA Interactive Practical Knowledge    Skills Job Offer Predicted_Class
# 8  >=8         Yes                Good      Good       Yes             Yes
# 1  >=8          No                Good  Moderate       Yes             Yes
# 5  >=9         Yes                Good  Moderate       Yes             Yes

# %% [markdown]
# - Find accuracy score.

# %%
accuracy_score(y_test, temp_data["Predicted_Class"])
# Out:
# 1.0

# %% [markdown]
# ### 3) Heart Disease Data

# %% [markdown]
# - Import the dataset.

# %%
heart_data: pd.DataFrame = pd.read_csv(
    r"..\Datasets\Week5\RF_Dataset1_heart_v2.csv",
    dtype={"sex": "category", "heart disease": "category"}
)
heart_data
# Out:
#      age sex   BP  cholestrol heart disease
# 0     70   1  130         322             1
# 1     67   0  115         564             0
# 2     57   1  124         261             1
# 3     64   1  128         263             0
# 4     74   0  120         269             0
# ..   ...  ..  ...         ...           ...
# 265   52   1  172         199             0
# 266   44   1  120         263             0
# 267   56   0  140         294             0
# 268   57   1  140         192             0
# 269   67   1  160         286             1
#
# [270 rows x 5 columns]

# %% [markdown]
# *All data is numeric, no need for one hot encoding.*

# %% [markdown]
# - Define feature vector and target variable.

# %% [markdown]
# *Feature vector:*

# %%
x: pd.DataFrame = heart_data.iloc[:, :-1]

# %% [markdown]
# *Target Variable:*

# %%
y: pd.Series = heart_data.iloc[:, -1]

# %% [markdown]
# - Create training and testing splits.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# *Training data:*

# %%
pd.concat([x_train, y_train], axis=1)
# Out:
#      age sex   BP  cholestrol heart disease
# 84    57   1  110         201             0
# 251   44   1  130         219             0
# 92    54   1  124         266             1
# 201   58   1  125         300             1
# 126   62   1  120         267             1
# ..   ...  ..  ...         ...           ...
# 20    67   1  120         229             1
# 188   62   0  140         394             0
# 71    57   0  120         354             0
# 106   51   1  100         222             0
# 102   49   0  130         269             0
#
# [189 rows x 5 columns]

# %% [markdown]
# *Testing data:*

# %%
pd.concat([x_test, y_test], axis=1)
# Out:
#      age sex   BP  cholestrol heart disease
# 30    57   1  128         229             1
# 116   46   1  120         249             1
# 79    56   1  120         236             0
# 127   52   0  136         196             0
# 196   58   0  100         248             0
# ..   ...  ..  ...         ...           ...
# 55    41   0  105         198             0
# 97    58   1  100         234             1
# 200   68   1  118         277             0
# 38    42   1  130         180             0
# 154   51   0  130         256             0
#
# [81 rows x 5 columns]

# %% [markdown]
# - Create classifier.

# %%
model: RandomForestClassifier = RandomForestClassifier(criterion="entropy", random_state=42)
model
# Out:
# RandomForestClassifier(criterion='entropy', random_state=42)

# %% [markdown]
# - Fit the model.

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=42)

# %% [markdown]
# - Plot the tree.

# %% [markdown]
# *A random forest contains multiple estimator trees which are used to find the optimal decision tree for calculation. To find the best tree for the data, we use the majority voting technique. Fitting all trees with same data and predicting results from same test sample, we can find a tree with the highest accuracy. This tree will be our required decision tree.*

# %%
# Convert categories into numeric data
# Because the trees are fitted with numeric codes for the categories
accuracies: list[float] = [accuracy_score(y_test.cat.codes, i.predict(x_test)) for i in model.estimators_]
req_tree: DecisionTreeClassifier = model.estimators_[accuracies.index(max(accuracies))]
req_tree
# Out:
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# ...

# %% [markdown]
# *Using `sklearn.tree.plot_tree`:*

# %%
plt.figure(figsize=(50, 50))
plot_tree(
    req_tree,
    feature_names=x.columns,
    class_names=y.unique(),
    rounded=True,
    filled=True
)
# Out:
# [Text(0.5173611111111112, 0.9705882352941176, 'BP <= 162.5\nentropy = 1.0\nsamples = 121\nvalue = [94, 95]\nclass = 0'),
#  Text(0.4895833333333333, 0.9117647058823529, 'sex <= 0.5\nentropy = 0.997\nsamples = 115\nvalue = [94, 82]\nclass = 1'),
#  Text(0.19444444444444445, 0.8529411764705882, 'BP <= 129.0\nentropy = 0.772\nsamples = 38\nvalue = [41, 12]\nclass = 1'),
#  Text(0.16666666666666666, 0.7941176470588235, 'entropy = 0.0\nsamples = 15\nvalue = [20, 0]\nclass = 1'),
#  Text(0.2222222222222222, 0.7941176470588235, 'BP <= 143.5\nentropy = 0.946\nsamples = 23\nvalue = [21, 12]\nclass = 1'),
#  Text(0.08333333333333333, 0.7352941176470589, 'cholestrol <= 253.5\nentropy = 0.887\nsamples = 14\nvalue = [16, 7]\nclass = 1'),
#  Text(0.05555555555555555, 0.6764705882352942, 'entropy = 0.0\nsamples = 6\nvalue = [11, 0]\nclass = 1'),
#  Text(0.1111111111111111, 0.6764705882352942, 'BP <= 139.0\nentropy = 0.98\nsamples = 8\nvalue = [5, 7]\nclass = 0'),
# ...

# %% [markdown]
# *Using `sklearn.tree.export_graphviz`:*

# %%
with open(r"Generated/heart_rf.txt", "x") as file:
    content: str = export_graphviz(
        req_tree,
        feature_names=x.columns,
        class_names=y.unique(),
        rounded=True,
        filled=True
    )
    file.write(content)
    print(content)
    file.close()
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label="BP <= 162.5\nentropy = 1.0\nsamples = 121\nvalue = [94, 95]\nclass = 0", fillcolor="#fdfeff"] ;
# 1 [label="sex <= 0.5\nentropy = 0.997\nsamples = 115\nvalue = [94, 82]\nclass = 1", fillcolor="#fcefe6"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="BP <= 129.0\nentropy = 0.772\nsamples = 38\nvalue = [41, 12]\nclass = 1", fillcolor="#eda673"] ;
# 1 -> 2 ;
# 3 [label="entropy = 0.0\nsamples = 15\nvalue = [20, 0]\nclass = 1", fillcolor="#e58139"] ;
# 2 -> 3 ;
# 4 [label="BP <= 143.5\nentropy = 0.946\nsamples = 23\nvalue = [21, 12]\nclass = 1", fillcolor="#f4c9aa"] ;
# 2 -> 4 ;
# 5 [label="cholestrol <= 253.5\nentropy = 0.887\nsamples = 14\nvalue = [16, 7]\nclass = 1", fillcolor="#f0b890"] ;
# 4 -> 5 ;
# 6 [label="entropy = 0.0\nsamples = 6\nvalue = [11, 0]\nclass = 1", fillcolor="#e58139"] ;
# 5 -> 6 ;
# ...

# %% [markdown]
# - Predict values for test set.

# %%
temp_data: pd.DataFrame = heart_data.loc[x_test.index, :]
temp_data["Predicted_Class"] = model.predict(x_test)

temp_data
# Out:
#      age sex   BP  cholestrol heart disease Predicted_Class
# 30    57   1  128         229             1               0
# 116   46   1  120         249             1               0
# 79    56   1  120         236             0               1
# 127   52   0  136         196             0               0
# 196   58   0  100         248             0               0
# ..   ...  ..  ...         ...           ...             ...
# 55    41   0  105         198             0               0
# 97    58   1  100         234             1               0
# 200   68   1  118         277             0               1
# 38    42   1  130         180             0               1
# 154   51   0  130         256             0               0
#
# [81 rows x 6 columns]

# %% [markdown]
# - Find accuracy score.

# %%
accuracy_score(y_test, temp_data["Predicted_Class"])
# Out:
# 0.5802469135802469

# %% [markdown]
# ### 4) Cylinder Bands Data

# %% [markdown]
# - Import the dataset.

# %%
cylinder_data: pd.DataFrame = pd.read_csv(
    r"..\Datasets\Week5\bands.data",
    header=None,
    names=[
        "timestamp",
        "cylinder number",
        "customer",
        "job number",
        "grain screened",
        "ink color",
        "proof on ctd ink",
        "blade mfg",
        "cylinder division",
        "paper type",
        "ink type",
        "direct steam",
        "solvent type",
        "type on cylinder",
        "press type",
        "press",
        "unit number",
        "cylinder size",
        "paper mill location",
        "plating tank",
        "proof cut",
        "viscosity",
        "caliper",
        "ink temperature",
        "humifity",
        "roughness",
        "blade pressure",
        "varnish pct",
        "press speed",
        "ink pct",
        "solvent pct",
        "ESA Voltage",
        "ESA Amperage",
        "wax",
        "hardener",
        "roller durometer", 
        "current density",
        "anode space ratio",
        "chrome content",
        "band type"
    ],
    dtype={"band type": "category"},
    na_values=["?"]
)
cylinder_data
# Out:
#     timestamp cylinder number customer  job number grain screened ink color  \
# 0    19910108            X126  TVGUIDE     25503.0            YES       KEY
# 1    19910109            X266  TVGUIDE     25503.0            YES       KEY
# 2    19910104              B7   MODMAT     47201.0            YES       KEY
# 3    19910104            T133   MASSEY     39039.0            YES       KEY
# 4    19910111             J34    KMART     37351.0             NO       KEY
# ..        ...             ...      ...         ...            ...       ...
# 536  19941005            aa66    kmart     85813.0            NaN       key
# 537  19941009             j44     best     38064.0            NaN       key
# 538  19941009            aa58    kmart     85814.0            NaN       key
# 539  19941010            aa70    kmart     85814.0            NaN       key
# 540  19941010             j70     best     38064.0            NaN       key
#
# ...

# %% [markdown]
# **Preprocessing:**

# %% [markdown]
# *Drop `timestamp` and `cylinder number` as they have too many distinct values.*

# %%
cylinder_data.drop(["timestamp", "cylinder number"], axis=1, inplace=True)
cylinder_data
# Out:
#     customer  job number grain screened ink color proof on ctd ink blade mfg  \
# 0    TVGUIDE     25503.0            YES       KEY              YES    BENTON
# 1    TVGUIDE     25503.0            YES       KEY              YES    BENTON
# 2     MODMAT     47201.0            YES       KEY              YES    BENTON
# 3     MASSEY     39039.0            YES       KEY              YES    BENTON
# 4      KMART     37351.0             NO       KEY              YES    BENTON
# ..       ...         ...            ...       ...              ...       ...
# 536    kmart     85813.0            NaN       key              NaN       NaN
# 537     best     38064.0            NaN       key              NaN       NaN
# 538    kmart     85814.0            NaN       key              NaN       NaN
# 539    kmart     85814.0            NaN       key              NaN       NaN
# 540     best     38064.0            NaN       key              NaN       NaN
#
# ...

# %% [markdown]
# *Check for missing data.*

# %%
cylinder_data.isna().sum()
# Out:
# customer                 0
# job number               1
# grain screened          49
# ink color                0
# proof on ctd ink        57
# blade mfg               60
# cylinder division        0
# paper type               0
# ink type                 1
# direct steam            25
# solvent type            56
# type on cylinder        19
# press type               1
# press                    1
# unit number              0
# cylinder size            4
# paper mill location    157
# plating tank            19
# proof cut               55
# viscosity                6
# caliper                 28
# ink temperature          4
# humifity                 3
# roughness               32
# blade pressure          65
# varnish pct             57
# press speed             12
# ink pct                 57
# solvent pct             57
# ESA Voltage             58
# ESA Amperage            56
# wax                      8
# hardener                 9
# roller durometer        56
# ...

# %% [markdown]
# *Drop missing data.*

# %%
cylinder_data.dropna(inplace=True)
cylinder_data.isna().sum()
# Out:
# customer               0
# job number             0
# grain screened         0
# ink color              0
# proof on ctd ink       0
# blade mfg              0
# cylinder division      0
# paper type             0
# ink type               0
# direct steam           0
# solvent type           0
# type on cylinder       0
# press type             0
# press                  0
# unit number            0
# cylinder size          0
# paper mill location    0
# plating tank           0
# proof cut              0
# viscosity              0
# caliper                0
# ink temperature        0
# humifity               0
# roughness              0
# blade pressure         0
# varnish pct            0
# press speed            0
# ink pct                0
# solvent pct            0
# ESA Voltage            0
# ESA Amperage           0
# wax                    0
# hardener               0
# roller durometer       0
# current density        0
# anode space ratio      0
# chrome content         0
# ...

# %% [markdown]
# - One hot encode the string data to make it numeric.

# %%
cylinder_coded: pd.DataFrame = pd.get_dummies(
    cylinder_data,
    columns=cylinder_data.select_dtypes(include="object").columns
)
cylinder_coded
# Out:
#      job number  press  unit number  plating tank  proof cut  viscosity  \
# 0       25503.0  821.0          2.0        1911.0       55.0       46.0
# 3       39039.0  816.0          9.0        1910.0       52.0       40.0
# 5       38039.0  816.0          2.0        1910.0       50.0       40.0
# 6       35751.0  827.0          2.0        1911.0       50.0       46.0
# 7       35751.0  827.0          9.0        1911.0       50.0       46.0
# ..          ...    ...          ...           ...        ...        ...
# 424     34590.0  827.0          2.0        1910.0       50.0       40.0
# 426     34693.0  828.0          9.0        1910.0       50.0       41.0
# 427     34694.0  824.0          2.0        1910.0       30.0       41.0
# 428     35525.0  815.0          2.0        1910.0       40.0       41.0
# 429     25502.0  821.0          2.0        1911.0       52.0       52.0
#
#      ink temperature  humifity  roughness  blade pressure  ...  caliper_0.267  \
# ...

# %% [markdown]
# - Define feature vector and target variable.

# %% [markdown]
# *Feature vector:*

# %%
x: pd.DataFrame = cylinder_coded[[i for i in cylinder_coded.columns if i != "band type"]]

# %% [markdown]
# *Target Variable:*

# %%
y: pd.Series = cylinder_coded["band type"]

# %% [markdown]
# - Create training and testing splits.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# *Training data:*

# %%
pd.concat([x_train, y_train], axis=1)
# Out:
#      job number  press  unit number  plating tank  proof cut  viscosity  \
# 56      37869.0  802.0          7.0        1911.0       35.0       38.0
# 327     34754.0  824.0          2.0        1910.0       42.5       48.0
# 219     36024.0  815.0          9.0        1910.0       52.5       54.0
# 97      35754.0  824.0          9.0        1910.0       47.0       43.0
# 416     25451.0  821.0          7.0        1910.0       55.0       40.0
# ..          ...    ...          ...           ...        ...        ...
# 311     34551.0  815.0          1.0        1910.0       40.0       60.0
# 121     37333.0  815.0          2.0        1910.0       35.0       56.0
# 165     37199.0  824.0          9.0        1910.0       40.0       64.0
# 420     34556.0  816.0          9.0        1910.0       37.5       40.0
# 160     37579.0  827.0          9.0        1910.0       45.0       69.0
#
#      ink temperature  humifity  roughness  blade pressure  ...  caliper_0.283  \
# ...

# %% [markdown]
# *Testing data:*

# %%
pd.concat([x_test, y_test], axis=1)
# Out:
#      job number  press  unit number  plating tank  proof cut  viscosity  \
# 47      37441.0  821.0          2.0        1911.0       25.0       38.0
# 194     36054.0  827.0          2.0        1910.0       45.0       55.0
# 355     36165.0  828.0          2.0        1910.0       65.0       42.0
# 218     36057.0  827.0          2.0        1910.0       30.0       58.0
# 403     27490.0  802.0          2.0        1910.0       32.0       42.0
# ..          ...    ...          ...           ...        ...        ...
# 145     35758.0  828.0          2.0        1910.0       40.0       62.0
# 272     36644.0  802.0          7.0        1910.0       60.0       53.0
# 95      35534.0  827.0          9.0        1910.0       45.0       44.0
# 337     36197.0  815.0          9.0        1911.0       47.5       53.0
# 340     38218.0  821.0          7.0        1911.0       30.0       52.0
#
#      ink temperature  humifity  roughness  blade pressure  ...  caliper_0.283  \
# ...

# %% [markdown]
# - Create classifier.

# %%
model: RandomForestClassifier = RandomForestClassifier(criterion="entropy", random_state=42)
model
# Out:
# RandomForestClassifier(criterion='entropy', random_state=42)

# %% [markdown]
# - Fit the model.

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=42)

# %% [markdown]
# - Plot the tree.

# %% [markdown]
# *A random forest contains multiple estimator trees which are used to find the optimal decision tree for calculation. To find the best tree for the data, we use the majority voting technique. Fitting all trees with same data and predicting results from same test sample, we can find a tree with the highest accuracy. This tree will be our required decision tree.*

# %%
# Convert categories into numeric data
# Because the trees are fitted with numeric codes for the categories
accuracies: list[float] = [accuracy_score(y_test.cat.codes, i.predict(x_test)) for i in model.estimators_]
req_tree: DecisionTreeClassifier = model.estimators_[accuracies.index(max(accuracies))]
req_tree
# Out:
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# g:\Installations\Development\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# ...

# %% [markdown]
# *Using `sklearn.tree.plot_tree`:*

# %%
plt.figure(figsize=(50, 50))
plot_tree(
    req_tree,
    feature_names=x.columns,
    class_names=y.unique(),
    rounded=True,
    filled=True
)
# Out:
# [Text(0.5469924812030075, 0.9642857142857143, 'press type_WoodHoe70 <= 0.5\nentropy = 0.941\nsamples = 120\nvalue = [69.0, 124.0]\nclass = noband'),
#  Text(0.33458646616541354, 0.8928571428571429, 'hardener <= 1.15\nentropy = 0.854\nsamples = 77\nvalue = [36, 93]\nclass = noband'),
#  Text(0.30451127819548873, 0.8214285714285714, 'paper mill location_NorthUS <= 0.5\nentropy = 0.912\nsamples = 64\nvalue = [36, 74]\nclass = noband'),
#  Text(0.09022556390977443, 0.75, 'blade pressure <= 29.0\nentropy = 0.489\nsamples = 29\nvalue = [5, 42]\nclass = noband'),
#  Text(0.06015037593984962, 0.6785714285714286, 'entropy = 0.0\nsamples = 12\nvalue = [0, 18]\nclass = noband'),
#  Text(0.12030075187969924, 0.6785714285714286, 'hardener <= 0.9\nentropy = 0.663\nsamples = 17\nvalue = [5, 24]\nclass = noband'),
#  Text(0.06015037593984962, 0.6071428571428571, 'viscosity <= 43.5\nentropy = 0.985\nsamples = 5\nvalue = [4, 3]\nclass = band'),
# ...

# %% [markdown]
# *Using `sklearn.tree.export_graphviz`:*

# %%
with open(r"Generated/cylinder_rf.txt", "x") as file:
    content: str = export_graphviz(
        req_tree,
        feature_names=x.columns,
        class_names=y.unique(),
        rounded=True,
        filled=True
    )
    file.write(content)
    print(content)
    file.close()
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label="press type_WoodHoe70 <= 0.5\nentropy = 0.941\nsamples = 120\nvalue = [69.0, 124.0]\nclass = noband", fillcolor="#a7d4f3"] ;
# 1 [label="hardener <= 1.15\nentropy = 0.854\nsamples = 77\nvalue = [36, 93]\nclass = noband", fillcolor="#86c3ef"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="paper mill location_NorthUS <= 0.5\nentropy = 0.912\nsamples = 64\nvalue = [36, 74]\nclass = noband", fillcolor="#99cdf2"] ;
# 1 -> 2 ;
# 3 [label="blade pressure <= 29.0\nentropy = 0.489\nsamples = 29\nvalue = [5, 42]\nclass = noband", fillcolor="#51a9e8"] ;
# 2 -> 3 ;
# 4 [label="entropy = 0.0\nsamples = 12\nvalue = [0, 18]\nclass = noband", fillcolor="#399de5"] ;
# 3 -> 4 ;
# 5 [label="hardener <= 0.9\nentropy = 0.663\nsamples = 17\nvalue = [5, 24]\nclass = noband", fillcolor="#62b1ea"] ;
# 3 -> 5 ;
# ...

# %% [markdown]
# - Predict values for test set.

# %%
temp_data: pd.DataFrame = cylinder_data.loc[x_test.index, :]
temp_data["Predicted_Class"] = model.predict(x_test)

temp_data
# Out:
#        customer  job number grain screened ink color proof on ctd ink  \
# 47     CENPURCH     37441.0             NO       KEY              YES
# 194       WARDS     36054.0             NO       KEY              YES
# 355       KMART     36165.0            YES       KEY              YES
# 218       WARDS     36057.0             NO       KEY              YES
# 403  ABBEYPRESS     27490.0             NO       KEY              YES
# ..          ...         ...            ...       ...              ...
# 145       ROSES     35758.0             NO       KEY              YES
# 272         REI     36644.0            YES       KEY              YES
# 95         BELK     35534.0            YES       KEY              YES
# 337       KMART     36197.0             NO       KEY              YES
# 340     BRENDLS     38218.0             NO       KEY              YES
#
#     blade mfg cylinder division paper type  ink type direct steam  ...  \
# ...

# %% [markdown]
# - Find accuracy score.

# %%
accuracy_score(y_test, temp_data["Predicted_Class"])
# Out:
# 0.8333333333333334
